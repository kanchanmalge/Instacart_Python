# %% [markdown]
# 01 Importing libraries

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os

# Section header: Data Import

#define the path for file location
path = r'C:\Users\kanch\Documents\10-08-2023 Instacart Basket Analysis\02 Data\Original Data'


# Load orders.csv into a dataframe
orders_path = os.path.join(path,"4.3_orders_products","orders.csv")
df_ords = pd.read_csv(orders_path)

# %%
# Load products.csv into a dataframe
products_path = os.path.join(path,"4.3_orders_products", "products.csv")
df_prods = pd.read_csv(products_path)

#load departments.csv into a dataframe

department_path = os.path.join(path, '4.4_departments','departments.csv')
df_dept = pd.read_csv(department_path)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#Find another identifier variable in the df_ords dataframe 
#that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.

df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
#Look for a variable in your df_ords dataframe with an unintuitive name and 
#change its name without overwriting the dataframe.

# Display the column names of df_ords
print("Column names of df_ords:", df_ords.columns)
print(df_ords.columns)
# Out:
# Column names of df_ords: Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
# Rename the unintuitive variable to a more intuitive name
df_ords.rename(columns={'order_dow':'orders_day_of_week'},inplace = True)

# %%
df_ords.head()
# Out:
#    order_id user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329       1    prior             1                   2
# 1   2398795       1    prior             2                   3
# 2    473747       1    prior             3                   3
# 3   2254736       1    prior             4                   4
# 4    431534       1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
# Calculate the frequency of orders for each hour
hourly_order_freq = df_ords['order_hour_of_day'].value_counts()

# Find the busiest hour
busiest_hour = hourly_order_freq.idxmax()
busiest_hour_freq = hourly_order_freq.max()

print("The busiest hour for placing orders is:", busiest_hour)
print("Frequency of orders during the busiest hour:", busiest_hour_freq)
# Out:
# The busiest hour for placing orders is: 10
# Frequency of orders during the busiest hour: 288418

# %%
#method 2
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
#Determine the meaning behind a value of 4 in the "department_id" 
#column within the df_prods dataframe using a data dictionary.

df_dept.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dept.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dept_t = df_dept.T

# %%
# Reset the index / header
df_dept_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Create a new header using what's in the zero row
new_header = df_dept_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dept_t_new = df_dept_t[1:]

# %%
df_dept_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# Use the new header
df_dept_t_new.columns = new_header

# %%
df_dept_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Create a data dictionary
data_dict = df_dept_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# The sales team in your client’s organization wants to know more about breakfast item sales. 
# Create a subset containing only the required information.

df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# Display the first few rows of the breakfast subset
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# They’d also like to see details about products that customers might use to throw dinner parties. 
# Your task is to find all observations from the entire dataframe that include items from the following departments: 
# alcohol, deli, beverages, and meat/seafood. You’ll need to present this subset to your client.

df_dinner = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]
df_dinner
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# It’s important that you keep track of total counts in your dataframes. 
# How many rows does the last dataframe you created have?

7650 rows and 5 columns

# %%
# Extract information about the customer with user_id 1
customer_info = df_ords[df_ords['user_id'] == '1']

# Display the information about the customer
customer_info
# Out:
#     order_id user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329       1    prior             1                   2
# 1    2398795       1    prior             2                   3
# 2     473747       1    prior             3                   3
# 3    2254736       1    prior             4                   4
# 4     431534       1    prior             5                   4
# 5    3367565       1    prior             6                   2
# 6     550135       1    prior             7                   1
# 7    3108588       1    prior             8                   1
# 8    2295261       1    prior             9                   1
# 9    2550362       1    prior            10                   4
# 10   1187899       1    train            11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %%
# Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the 
# customer with a "user_id" of “1.” Extract all the information you can about this user.

df_ords_user1 = df_ords[df_ords['user_id']=='1']

# %%
df_ords_user1
# Out:
#     order_id user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329       1    prior             1                   2
# 1    2398795       1    prior             2                   3
# 2     473747       1    prior             3                   3
# 3    2254736       1    prior             4                   4
# 4     431534       1    prior             5                   4
# 5    3367565       1    prior             6                   2
# 6     550135       1    prior             7                   1
# 7    3108588       1    prior             8                   1
# 8    2295261       1    prior             9                   1
# 9    2550362       1    prior            10                   4
# 10   1187899       1    train            11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %%
# You also need to provide some details about this user’s behavior. 
# What basic stats can you provide based on the information you have?

df_ords_user1.describe()
# Out:
#            order_id  order_number  orders_day_of_week  order_hour_of_day  \
# count  1.100000e+01     11.000000           11.000000          11.000000
# mean   1.923450e+06      6.000000            2.636364          10.090909
# std    1.071950e+06      3.316625            1.286291           3.477198
# min    4.315340e+05      1.000000            1.000000           7.000000
# 25%    8.690170e+05      3.500000            1.500000           7.500000
# 50%    2.295261e+06      6.000000            3.000000           8.000000
# 75%    2.544846e+06      8.500000            4.000000          13.000000
# max    3.367565e+06     11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# Export wrangled department data
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))

# %%
path
# Out:
# 'C:\\Users\\kanch\\Documents\\10-08-2023 Instacart Basket Analysis\\02 Data\\Original Data'

# %%
# Export wrangled orders data

df_ords.to_csv(os.path.join('C:/Users/kanch/Documents/10-08-2023 Instacart Basket Analysis/02 Data/Prepared Data', 'orders_wrangled.csv'))

# %%
# Export wrangled department data

df_dept_t_new.to_csv(os.path.join('C:/Users/kanch/Documents/10-08-2023 Instacart Basket Analysis/02 Data/Prepared Data', 'departments_wrangled.csv'))

# %%
path
# Out:
# 'C:\\Users\\kanch\\Documents\\10-08-2023 Instacart Basket Analysis\\02 Data\\Original Data'
